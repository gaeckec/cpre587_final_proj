# %% [markdown]
# Generate Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

bandwidth_limit = 76800000000   # DRAM limited, 76.8 GB/s
perf_limit = 88472e6            # 88,472 MOps/sec

intercept = perf_limit / bandwidth_limit
print(bandwidth_limit, perf_limit, intercept)
# Out:
# 76800000000 88472000000.0 1.1519791666666668

# %% [markdown]
# Plot Part #1

# %%
# Values are from excel sheet

layer1_y = perf_limit * 1
layer1_x = 16.85
if layer1_x < intercept :
    layer1_y = bandwidth_limit * layer1_x

layer2_y = perf_limit * 1
layer2_x = 833.33
if layer2_x < intercept :
    layer2_y = bandwidth_limit * layer2_x

# layer3_y = perf_limit * 1
# layer3_x = 21.99
# if layer3_x < intercept :
#     layer3_y = bandwidth_limit * layer3_x

layer4_y = perf_limit * 1
layer4_x = 36.02
if layer4_x < intercept :
    layer4_y = bandwidth_limit * layer4_x

layer5_y = perf_limit * 1
layer5_x = 45.45
if layer5_x < intercept :
    layer5_y = bandwidth_limit * layer5_x

# layer6_y = perf_limit * 1
# layer6_x = 55.26
# if layer6_x < intercept :
#     layer6_y = bandwidth_limit * layer6_x

layer7_y = perf_limit * 1
layer7_x = 17.59
if layer7_x < intercept :
    layer7_y = bandwidth_limit * layer7_x

layer8_y = perf_limit * 1
layer8_x = 13.38
if layer8_x < intercept :
    layer8_y = bandwidth_limit * layer8_x

layer11_y = perf_limit * 1
layer11_x = 0.25
if layer11_x < intercept :
    layer11_y = bandwidth_limit * layer11_x

layer12_y = perf_limit * 1
layer12_x = 0.25
if layer12_x < intercept :
    layer12_y = bandwidth_limit * layer12_x

layer13_y = perf_limit * 1
layer13_x = 0.25
if layer13_x < intercept :
    layer13_y = bandwidth_limit * layer13_x
    


plt.figure(figsize=[15, 6])
plt.yscale("linear")
plt.ylim(1e0, 3e11)
plt.ylabel("ops/sec")
plt.xlabel("ops/byte")
plt.xlim(0, 70)
plt.axhline(y=perf_limit, color='r', label="Performance Limit")
plt.axvline(x=intercept, color='0.55', linestyle='dashed')
x = np.arange(0, 71, 1)
plt.plot(x, bandwidth_limit*x, label="Bandwidth Limit")

plt.plot(layer1_x, layer1_y, '-gX', label="Layer 1")
plt.plot(layer2_x, layer2_y, '-bX', label="Layer 2")
plt.plot(layer3_x, layer3_y, '-mX', label="Layer 3")
plt.plot(layer4_x, layer4_y, '-yX', label="Layer 4")
plt.plot(layer_total_x, layer_total_y, '-kX', label="Total")


plt.legend(loc="best")
plt.show()

# %% [markdown]
# Plot Part #2

# %%
# Values are from excel sheet

layer1_y = perf_limit * 1
layer1_x = 13.36
if layer1_x < intercept :
    layer1_y = bandwidth_limit * layer1_x

layer2_y = perf_limit * 0.77
layer2_x = 110.52
if layer2_x < intercept :
    layer2_y = bandwidth_limit * layer2_x

layer3_y = perf_limit * 0.77
layer3_x = 43.98
if layer3_x < intercept :
    layer3_y = bandwidth_limit * layer3_x

layer4_y = perf_limit * 0.89
layer4_x = 0.47
if layer4_x < intercept :
    layer4_y = bandwidth_limit * layer4_x

layer_total_y = 169554530735
layer_total_x = 37.44
if layer_total_x < intercept :
    layer4_y = bandwidth_limit * layer_total_x


plt.figure(figsize=[15, 6])
plt.yscale("linear")
plt.ylim(1e0, 3e11)
plt.ylabel("ops/sec")
plt.xlabel("ops/byte")
plt.xlim(0, 120)
plt.axhline(y=perf_limit, color='r', label="Performance Limit")
plt.axvline(x=intercept, color='0.55', linestyle='dashed')
x = np.arange(0, 71, 1)
plt.plot(x, bandwidth_limit*x, label="Bandwidth Limit")

plt.plot(layer1_x, layer1_y, '-gX', label="Layer 1")
plt.plot(layer2_x, layer2_y, '-bX', label="Layer 2")
plt.plot(layer3_x, layer3_y, '-mX', label="Layer 3")
plt.plot(layer4_x, layer4_y, '-yX', label="Layer 4")
plt.plot(layer_total_x, layer_total_y, '-kX', label="Total")


plt.legend(loc="best")
plt.show()

# %% [markdown]
# Plot Part #3

# %%
# Values are from excel sheet

layer1_y = perf_limit * 1
layer1_x = 53.43
if layer1_x < intercept :
    layer1_y = bandwidth_limit * layer1_x

layer2_y = perf_limit * 0.77
layer2_x = 442.08
if layer2_x < intercept :
    layer2_y = bandwidth_limit * layer2_x

layer3_y = perf_limit * 0.77
layer3_x = 175.94
if layer3_x < intercept :
    layer3_y = bandwidth_limit * layer3_x

layer4_y = perf_limit * 0.89
layer4_x = 1.88
if layer4_x < intercept :
    layer4_y = bandwidth_limit * layer4_x

layer_total_y = 192223136430
layer_total_x = 139.10
if layer_total_x < intercept :
    layer4_y = bandwidth_limit * layer_total_x


plt.figure(figsize=[15, 6])
plt.yscale("linear")
plt.ylim(1e0, 3e11)
plt.ylabel("ops/sec")
plt.xlabel("ops/byte")
plt.xlim(0, 470)
plt.axhline(y=perf_limit, color='r', label="Performance Limit")
plt.axvline(x=intercept, color='0.55', linestyle='dashed')
x = np.arange(0, 71, 1)
plt.plot(x, bandwidth_limit*x, label="Bandwidth Limit")

plt.plot(layer1_x, layer1_y, '-gX', label="Layer 1")
plt.plot(layer2_x, layer2_y, '-bX', label="Layer 2")
plt.plot(layer3_x, layer3_y, '-mX', label="Layer 3")
plt.plot(layer4_x, layer4_y, '-yX', label="Layer 4")
plt.plot(layer_total_x, layer_total_y, '-kX', label="Total")


plt.legend(loc="best")
plt.show()
